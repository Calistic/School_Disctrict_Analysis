# %%
import pandas as pd
import os

# %%
file_to_load = "ufoSightings.csv"

ufoDF = pd.read_csv(file_to_load)

print(file_to_load)
# Out:
# ufoSightings.csv

# %%
cleanUFODF = ufoDF.dropna(how='any')

# %%
cleanUFODF['duration (seconds)'].apply(type)
# Out:
# 0          <class 'str'>
# 3          <class 'str'>
# 4          <class 'str'>
# 5          <class 'str'>
# 7          <class 'str'>
#               ...
# 80327    <class 'float'>
# 80328    <class 'float'>
# 80329    <class 'float'>
# 80330    <class 'float'>
# 80331    <class 'float'>
# Name: duration (seconds), Length: 66516, dtype: object

# %%
castDurationDF = cleanUFODF.copy()
castDurationDF["duration (seconds)"] = castDurationDF.loc[:, "duration (seconds)"].astype(float)
castDurationDF["duration (seconds)"].apply(type)
# Out:
# 0        <class 'float'>
# 3        <class 'float'>
# 4        <class 'float'>
# 5        <class 'float'>
# 7        <class 'float'>
#               ...
# 80327    <class 'float'>
# 80328    <class 'float'>
# 80329    <class 'float'>
# 80330    <class 'float'>
# 80331    <class 'float'>
# Name: duration (seconds), Length: 66516, dtype: object

# %%
usaOnlySightings = castDurationDF.loc[castDurationDF["country"] == "us", :]
print(len(usaOnlySightings))
# Out:
# 63553

# %%
#value_counts: count qty of each unique entry
stateCounts = usaOnlySightings["state"].value_counts()

# %%
groupByState = usaOnlySightings.groupby('state')
groupByStateValues = groupByState.count()
print(groupByStateValues)
# Out:
#        datetime  city  country  shape  duration (seconds)  \
# state
# ak          311   311      311    311                 311
# al          629   629      629    629                 629
# ar          578   578      578    578                 578
# az         2362  2362     2362   2362                2362
# ca         8683  8683     8683   8683                8683
# co         1385  1385     1385   1385                1385
# ct          865   865      865    865                 865
# dc            7     7        7      7                   7
# de          165   165      165    165                 165
# fl         3754  3754     3754   3754                3754
# ga         1235  1235     1235   1235                1235
# hi          257   257      257    257                 257
# ia          669   669      669    669                 669
# id          508   508      508    508                 508
# il         2447  2447     2447   2447                2447
# ...

# %%
groupByStateDurationSumDF = groupByState["duration (seconds)"].sum()
groupByStateDurationAVGDF = groupByState["duration (seconds)"].mean()

# %%
file_to_load_poke = "Pokemon.csv"

pokeDF = pd.read_csv(file_to_load_poke)

print(file_to_load_poke)
# Out:
# Pokemon.csv

# %%
#average stat grouped by type 1

groupByType = pokeDF.groupby("Type 1")

# %%
pokeDF.head(100)
# Out:
#      #                   Name  Type 1  Type 2  Total   HP  Attack  Defense  \
# 0    1              Bulbasaur   Grass  Poison    318   45      49       49
# 1    2                Ivysaur   Grass  Poison    405   60      62       63
# 2    3               Venusaur   Grass  Poison    525   80      82       83
# 3    3  VenusaurMega Venusaur   Grass  Poison    625   80     100      123
# 4    4             Charmander    Fire     NaN    309   39      52       43
# ..  ..                    ...     ...     ...    ...  ...     ...      ...
# 95  88                 Grimer  Poison     NaN    325   80      80       50
# 96  89                    Muk  Poison     NaN    500  105     105       75
# 97  90               Shellder   Water     NaN    305   30      65      100
# 98  91               Cloyster   Water     Ice    525   50      95      180
# 99  92                 Gastly   Ghost  Poison    310   30      35       30
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
groupByTypeAvgHP = groupByType["HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"].mean() 
groupByTypeAvgHP.head(100)
# Out:
#                  HP      Attack     Defense    Sp. Atk    Sp. Def       Speed
# Type 1
# Bug       56.884058   70.971014   70.724638  53.869565  64.797101   61.681159
# Dark      66.806452   88.387097   70.225806  74.645161  69.516129   76.161290
# Dragon    83.312500  112.125000   86.375000  96.843750  88.843750   83.031250
# Electric  59.795455   69.090909   66.295455  90.022727  73.704545   84.500000
# Fairy     74.117647   61.529412   65.705882  78.529412  84.705882   48.588235
# Fighting  69.851852   96.777778   65.925926  53.111111  64.703704   66.074074
# Fire      69.903846   84.769231   67.769231  88.980769  72.211538   74.442308
# Flying    70.750000   78.750000   66.250000  94.250000  72.500000  102.500000
# Ghost     64.437500   73.781250   81.187500  79.343750  76.468750   64.343750
# Grass     67.271429   73.214286   70.800000  77.500000  70.428571   61.928571
# Ground    73.781250   95.750000   84.843750  56.468750  62.750000   63.906250
# ...

# %%
pokeHeader = groupByType[0]
pokeHeader.head(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-64d0bdad94df> in <module>
# ----> 1 pokeHeader = groupByType[0]
#       2 pokeHeader.head(1)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     266         else:
#     267             if key not in self.obj:
# --> 268                 raise KeyError("Column not found: {key}".format(key=key))
#     269             return self._gotitem(key, ndim=1)
#     270
#
# KeyError: 'Column not found: 0'
